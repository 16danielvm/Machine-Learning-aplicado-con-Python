# %% [markdown]
# Visualizar interdependencia entre variables

# %%
import pandas as pd
X = pd.read_csv('X.csv')

# %%
import seaborn as sns
# %matplotlib inline

sns.heatmap(X.corr())
# Out:
# <AxesSubplot:>
